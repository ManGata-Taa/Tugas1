# %% [markdown]
# <a href="https://colab.research.google.com/github/ManGata-Taa/Tugas1/blob/main/Tugas01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Membuat array untuk menyimpan nilai

# %%
data_nilai = []

# %% [markdown]
# Program untuk memasukkan ke data

# %%
for i in range(10):
    angka = int(input(f"Input nilai ke-{i+1}: "))
    data_nilai.append(angka)
# Out:
# Input nilai ke-1: 70
# Input nilai ke-2: 80
# Input nilai ke-3: 75
# Input nilai ke-4: 776
# Input nilai ke-5: 95
# Input nilai ke-6: 99
# Input nilai ke-7: 100
# Input nilai ke-8: 35
# Input nilai ke-9: 34
# Input nilai ke-10: 66

# %% [markdown]
# Menghitung jumlah mahasiswa yang lulus

# %%
jumlah_lulus = 0
for x in data_nilai:
    if x >= 60:
        jumlah_lulus += 1

# %% [markdown]
# Menampilkan hasil

# %%
print("===== HASIL PERHITUNGAN =====")
print("Data Nilai        :", data_nilai)
print("Nilai Maksimum    :", max(data_nilai))
print("Nilai Minimum     :", min(data_nilai))
print("Rata-rata Nilai   :", sum(data_nilai)/len(data_nilai))
print("Total Lulus       :", jumlah_lulus)
print("Total Tidak Lulus :", len(data_nilai) - jumlah_lulus)
# Out:
# ===== HASIL PERHITUNGAN =====
# Data Nilai        : [70, 80, 75, 776, 95, 99, 100, 35, 34, 66]
# Nilai Maksimum    : 776
# Nilai Minimum     : 34
# Rata-rata Nilai   : 143.0
# Total Lulus       : 8
# Total Tidak Lulus : 2

# %% [markdown]
# Grafik Perbandingan Nilai

# %%
import matplotlib.pyplot as plt

# Label untuk grafik batang
label_gfk = ["Nilai Tertinggi", "Nilai Terendah"]
data_gfk = [nilai_tertinggi, nilai_terendah]

plt.bar(label_gfk, data_gfk)
plt.title("Grafik Perbandingan Nilai")
plt.ylabel("Nilai")
plt.show()

# %% [markdown]
# Grafik Persentase Kelulusan

# %%
import matplotlib.pyplot as plt

# Data kelulusan
label_pie = ["Lulus", "Tidak Lulus"]
data_pie = [jumlah_lulus, jumlah_tidak_lulus]

plt.pie(data_pie, labels=label_pie, autopct='%1.1f%%')
plt.title("Grafik Persentase Kelulusan")
plt.axis('equal')
plt.show()
